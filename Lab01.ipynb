// %%
#include <iostream>
#include <math.h>
using namespace std;
    bool loop = true;
    int Turn = 0;
    int a;
    int First_Row = 1;
    int Second_Row = 3;
    int Third_Row = 5;
    int Fourth_Row = 7;
    bool First_Player = true;
    cout << "Welcome to Nim please pass the control to player 1 ";
// Out:
// Welcome to Nim please pass the control to player 1
// @0x7f5b1767f660

// %%
while(loop){
    while(First_Row > 0 || Second_Row > 0 || Third_Row > 0 || Fourth_Row > 0){
        if(First_Row) {cout << "Row 1: "<< First_Row << "\n";}
        if(Second_Row) {cout << "Row 2: " << Second_Row << "\n";}
        if(Third_Row) {cout << "Row 3: " << Third_Row << "\n";}
        if(Fourth_Row){ cout << "Row 4: " << Fourth_Row << "\n";}
        Turn = ++Turn;
        cout << "Turn: " << Turn;

        
        if(First_Player){
            cout << "\n[PLAYER 1] Please pick from one of the 4 rows: ";
            cin >> a; 
            switch (a)
            {
            case 1:
                if(First_Row == 0){
                    cout << "uh oh its empty\n";
                }
                else{
                    cout << "how many do you want to remove? ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= First_Row) {
                        First_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 1.\n";
                        First_Player = !First_Player; // Switch turns

                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;
            
            case 2:
                if (Second_Row == 0) {
                    cout << "Row 2 is empty! Choose another row.\n";
                } else {
                    cout << "How many sticks to remove (1 to " << Second_Row << "): ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= Second_Row) {
                        Second_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 2.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;

            case 3:
                if (Third_Row == 0) {
                    cout << "Row 3 is empty! Choose another row.\n";
                } else {
                    cout << "How many sticks to remove (1 to " << Third_Row << "): ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= Third_Row) {
                        Third_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 3.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;

            case 4:
                if (Fourth_Row == 0) {
                    cout << "Row 4 is empty! Choose another row.\n";
                } else {
                    cout << "How many sticks to remove (1 to " << Fourth_Row << "): ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= Fourth_Row) {
                        Fourth_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 4.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;

            default:
                cout << "Invalid row choice! Please select 1, 2, 3, or 4.\n";
                break;
            }
        }
        else{
            cout << "\n[PLAYER 2] Please pick from one of the 4 rows: ";
            cin >> a; 
            switch (a)
            {
            case 1:
                if(First_Row == 0){
                    cout << "uh oh its empty\n";
                }
                else{
                    cout << "how many do you want to remove? ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= First_Row) {
                        First_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 1.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;
            
            case 2:
                if (Second_Row == 0) {
                    cout << "Row 2 is empty! Choose another row.\n";
                } else {
                    cout << "How many sticks to remove (1 to " << Second_Row << "): ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= Second_Row) {
                        Second_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 2.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;

            case 3:
                if (Third_Row == 0) {
                    cout << "Row 3 is empty! Choose another row.\n";
                } else {
                    cout << "How many sticks to remove (1 to " << Third_Row << "): ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= Third_Row) {
                        Third_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 3.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;

            case 4:
                if (Fourth_Row == 0) {
                    cout << "Row 4 is empty! Choose another row.\n";
                } else {
                    cout << "How many sticks to remove (1 to " << Fourth_Row << "): ";
                    cin >> a;
                    if (a >= 1 && a <= 4 && a <= Fourth_Row) {
                        Fourth_Row -= a;
                        cout << "Removed " << a << " stick(s) from Row 4.\n";
                        First_Player = !First_Player; // Switch turns
                    } 
                    else {
                        cout << "Invalid amount! Try again.\n";
                    }
                }
                break;

            default:
                cout << "Invalid row choice! Please select 1, 2, 3, or 4.\n";
                break;
            }
        }
    }

    // GAME OVER MESSAGE
    cout << "\n========================\n";
    cout << "GAME OVER!\n";
    if (First_Player) {
        cout << "Player 1 Wins!\n";
    } else {
        cout << "Player 2 Wins!\n";
    }
    cout << "========================\n";
    cout << "Do you want to play again?";
    char option;
    cin >> option;
    if(option == 'Y' || option == 'y'){
    First_Row = 1;
    Second_Row = 3;
    Third_Row = 5;
    Fourth_Row = 7;
    }
else{
    cout << "Thanks for playing";
    break;
}
}
    return 0;
// Out:
// Row 1: 1
// Row 2: 3
// Row 3: 5
// Row 4: 7
// Turn 1
// [PLAYER 1] Please pick from one of the 4 rows:
//  1
// how many do you want to remove?
//  1
// Removed 1 stick(s) from Row 1.
// Row 2: 3
// Row 3: 5
// Row 4: 7
// Turn 2
// [PLAYER 2] Please pick from one of the 4 rows:
